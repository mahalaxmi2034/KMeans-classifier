# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalaxmi2034/KMeans-classifier/blob/main/kmeans_practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libs
import pandas as pd
#reading the dataset
df=pd.read_csv('/content/Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#droping columns
#default axis=0 i.e.. row as we need to del column axis=1

df=df.drop(['CustomerID'],axis=1)

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#visualizing the distribution
#ploting the age freq of customer   -voilin plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
plt.title('Age Frequency')
sns.violinplot(y=df["Age"])
plt.show()

# %%
#box plot of spending score and annual income for better viualization 
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.boxplot(y=df["Spending Score (1-100)"],color="red")
plt.subplot(1,2,2)
sns.boxplot(y=df["Annual Income (k$)"],color="blue")
plt.show()

# %%
'''genders=df.Gender.count()
plt.figure(figsize=(10,4))
sns.barplot(X=genders.index,Y=genders.values)    #indexes=M,F -x axis,genders={age, values} -y axis
plt.show()'''
# Out:
# 'genders=df.Gender.count()\nplt.figure(figsize=(10,4))\nsns.barplot(X=genders.index,Y=genders.values)    #indexes=M,F -x axis,genders={age, values} -y axis\nplt.show()'

# %%
df["Age"]
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %% [markdown]
# filtering the data frame with & condtn to keep rows with a particular column

# %%
#distribution of customers in diff age gps
age18_25 = df['Age'][(df["Age"]>=18)&(df["Age"]<=25)]
age26_35 = df['Age'][(df["Age"]>=26)&(df["Age"]<=35)]
age36_45 = df['Age'][(df["Age"]>=36)&(df["Age"]<=45)]
age46_55 = df['Age'][(df["Age"]>=46)&(df["Age"]<=555)]
age55above =df['Age'][(df["Age"]>=56)]

# %%
x=["18-25","26-35","36-45","46-55","56+"]
y=[len(age18_25),len(age26_35),len(age36_45),len(age46_55),len(age55above)]
plt.figure(figsize=(15,6))
sns.barplot(x,y)
plt.title("No.of Customers in diff age gps")
plt.xlabel("Age")
plt.ylabel("No.of Customers")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# therefore clearly b/w 26-35 age gp there are more customers

# %%
#lets visualize the number of customers accorsing to spending scores
ss1_20 =df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=1)&(df["Spending Score (1-100)"]<=20)]
ss21_40 =df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=21)&(df["Spending Score (1-100)"]<=40)]
ss41_60 =df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=41)&(df["Spending Score (1-100)"]<=60)]
ss61_80=df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=61)&(df["Spending Score (1-100)"]<=80)]
ss81_100 =df["Spending Score (1-100)"][(df["Spending Score (1-100)"]>=81)&(df["Spending Score (1-100)"]<=100)]

# %%
x=["1-20","21-40","41-60","61-80","81-100"]
y=[len(ss1_20),len(ss21_40),len(ss41_60),len(ss61_80),len(ss81_100)]
plt.figure(figsize=(15,6))
sns.barplot(x,y)
plt.title("No.of Customers nd their spending scores")
plt.xlabel("Spending Score (1-100)")
plt.ylabel("No.of Customers")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#lets visualize the number of customers accorsing to spending scores
ai1_30 =df["Annual Income (k$)"][(df["Annual Income (k$)"]>=1)&(df["Annual Income (k$)"]<=30)]
ai31_60 =df["Annual Income (k$)"][(df["Annual Income (k$)"]>=31)&(df["Annual Income (k$)"]<=60)]
ai61_90 =df["Annual Income (k$)"][(df["Annual Income (k$)"]>=61)&(df["Annual Income (k$)"]<=90)]
ai91_120=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=91)&(df["Annual Income (k$)"]<=120)]
ai121_150 =df["Annual Income (k$)"][(df["Annual Income (k$)"]>=121)&(df["Annual Income (k$)"]<=150)]

# %%
x=["1-30","31-60","61-90","91-120","121-150"]
y=[len(ai1_30),len(ai31_60 ),len(ai61_90),len(ai91_120),len(ai121_150)]
plt.figure(figsize=(15,6))
sns.barplot(x,y)
plt.title("No.of Customers nd their annual income")
plt.xlabel("annual income")
plt.ylabel("No.of Customers")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.iloc[:,-3:]
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
#unsupervised
#training the model
from sklearn.cluster import KMeans 
km = KMeans(n_clusters=2)
clusters=km.fit_predict(df.iloc[:,-3:])

# %%
df['label']=clusters

# %%
df
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  label
# 0      Male   19                  15                      39      1
# 1      Male   21                  15                      81      0
# 2    Female   20                  16                       6      1
# 3    Female   23                  16                      77      0
# 4    Female   31                  17                      40      1
# ..      ...  ...                 ...                     ...    ...
# 195  Female   35                 120                      79      0
# 196  Female   45                 126                      28      1
# 197    Male   32                 126                      74      0
# 198    Male   32                 137                      18      1
# 199    Male   30                 137                      83      0
#
# [200 rows x 5 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
fig = plt.figure(figsize=(60,40))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Annual Income (k$)"][df.label == 0], df["Spending Score (1-100)"][df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Annual Income (k$)"][df.label == 1], df["Spending Score (1-100)"][df.label == 1], c='red', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %%
#elbow point to find optimal K value
import numpy as np
from sklearn.cluster import KMeans 
wcss=[]
for k in range(1,11):
  kmeans = KMeans(n_clusters=k,init="k-means++")
  kmeans.fit(df.iloc[:,-3:])
  wcss.append(kmeans.inertia_)

plt.figure(figsize=(15,6))
plt.grid()
plt.plot(range(1,11),wcss,linewidth=2,color="red",marker="+")
plt.xlabel("K Values")
plt.xticks(np.arrange(1,11,1))
plt.ylabel("variance-error (wcss)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-6c85a5fd1b8c> in <module>()
#      12 plt.plot(range(1,11),wcss,linewidth=2,color="red",marker="+")
#      13 plt.xlabel("K Values")
# ---> 14 plt.xticks(np.arrange(1,11,1))
#      15 plt.ylabel("variance-error (wcss)")
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
#unsupervised
#training the model
from sklearn.cluster import KMeans 
km = KMeans(n_clusters=5)
clusters=km.fit_predict(df.iloc[:,-3:])

# %%
df['label']=clusters

# %%
df
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  label
# 0      Male   19                  15                      39      3
# 1      Male   21                  15                      81      0
# 2    Female   20                  16                       6      3
# 3    Female   23                  16                      77      0
# 4    Female   31                  17                      40      3
# ..      ...  ...                 ...                     ...    ...
# 195  Female   35                 120                      79      2
# 196  Female   45                 126                      28      1
# 197    Male   32                 126                      74      2
# 198    Male   32                 137                      18      1
# 199    Male   30                 137                      83      2
#
# [200 rows x 5 columns]

# %% [markdown]
# i want to male a 3d plot to visualize the spending scores of customers with annual income

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.label == 0], df["Annual Income (k$)"][df.label == 0], df["Spending Score (1-100)"][df.label == 0], c='blue', s=60)
ax.scatter(df.Age[df.label == 1], df["Annual Income (k$)"][df.label == 1], df["Spending Score (1-100)"][df.label == 1], c='red', s=60)
ax.scatter(df.Age[df.label == 2], df["Annual Income (k$)"][df.label == 2], df["Spending Score (1-100)"][df.label == 2], c='green', s=60)
ax.scatter(df.Age[df.label == 3], df["Annual Income (k$)"][df.label == 3], df["Spending Score (1-100)"][df.label == 3], c='orange', s=60)
ax.scatter(df.Age[df.label == 4], df["Annual Income (k$)"][df.label == 4], df["Spending Score (1-100)"][df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %%
#predicting the cluster of new customer
age = int(input("Enter age"))
annual_income=int(input("Enter annual income"))
spend_score=int(input("Enter spending score"))
res_cluster=km.predict([[age,annual_income,spend_score]])
# Out:
# Enter age30
# Enter annual income39
# Enter spending score36
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print("new customer belongs to cluster:",res_cluster[0])
# Out:
# new customer belongs to cluster: 3
